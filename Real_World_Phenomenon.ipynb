# %%
# Load Libraries

from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib.ticker as mticker
import numpy as np

# %%
# Plot style.
plt.style.use("ggplot")

# Make matplotlib show interactive plots in the notebook.
# %matplotlib inline

# Plot size.
plt.rcParams['figure.figsize'] = [14, 8]

# %%
minimum = 50
maximum = 120
number_stops = 20
passenger_transported = [random.randint(minimum,maximum) for _ in range(20)]

plt.gca().xaxis.set_major_locator(mticker.MultipleLocator(1))
plt.xticks(np.arange(len(passenger_transported)), np.arange(1, len(passenger_transported)+1))
plt.xlabel('Number_stops')
plt.ylabel('Number passingers')
plt.plot(passinger_transported,"-")
# Out:
# [88, 61, 50, 111, 104, 90, 94, 109, 107, 50, 100, 88, 86, 84, 99, 95, 86, 56, 69, 102]
# 1729
